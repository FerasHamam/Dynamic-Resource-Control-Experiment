# %% [markdown]
# # Experiment #2: Open vSwitch 4 Networks 2 Bridge Nodes 1 Shared Link

# %% [markdown]
# In this experiment we try to connect 4 networks with different hosts together with a bridge in the middle. We will be using Open vSwitch for the bridge, alternate solutions are Linux Bridge and Behavioral Model (BMv2).

# %% [markdown]
# ## References
# - [Open vSwitch Example](https://github.com/fabric-testbed/jupyter-examples/blob/main/fabric_examples/complex_recipes/openvswitch/openvswitch.ipynb)
# - [BMv4](https://github.com/p4lang/behavioral-model)

# %% [markdown]
# ## TODO's
#
# - Add Open vSwitch flow configuratation on ports and so on.
# - Add tools on how to track packets in the bridge.
# - measure of congestion.

# %% [markdown]
# ## Topology

# %% [markdown]
# <img src="./fig/Testbed-openvswitch-2.png" width=90%>

# %% [markdown]
# ## Code

# %%
from ipaddress import ip_address, IPv4Address, IPv4Network
import ipaddress
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager


fablib = fablib_manager()
fablib.show_config();
# Out:
# <style type="text/css">
# #T_fe026 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_fe026 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_fe026 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_fe026_row0_col0, #T_fe026_row0_col1, #T_fe026_row1_col0, #T_fe026_row1_col1, #T_fe026_row2_col0, #T_fe026_row2_col1, #T_fe026_row3_col0, #T_fe026_row3_col1, #T_fe026_row4_col0, #T_fe026_row4_col1, #T_fe026_row5_col0, #T_fe026_row5_col1, #T_fe026_row6_col0, #T_fe026_row6_col1, #T_fe026_row7_col0, #T_fe026_row7_col1, #T_fe026_row8_col0, #T_fe026_row8_col1, #T_fe026_row9_col0, #T_fe026_row9_col1, #T_fe026_row10_col0, #T_fe026_row10_col1, #T_fe026_row11_col0, #T_fe026_row11_col1, #T_fe026_row12_col0, #T_fe026_row12_col1, #T_fe026_row13_col0, #T_fe026_row13_col1, #T_fe026_row14_col0, #T_fe026_row14_col1, #T_fe026_row15_col0, #T_fe026_row15_col1, #T_fe026_row16_col0, #T_fe026_row16_col1, #T_fe026_row17_col0, #T_fe026_row17_col1, #T_fe026_row18_col0, #T_fe026_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_fe026">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fe026_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_fe026_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_fe026_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_fe026_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_fe026_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_fe026_row4_col1" class="data row4 col1" >/home/alphani/.fabric_token.json</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_fe026_row5_col1" class="data row5 col1" >220c2d8a-ae05-465a-a98b-8178415e1b30</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_fe026_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_fe026_row7_col1" class="data row7 col1" >sa2994_0000240697</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_fe026_row8_col1" class="data row8 col1" >/home/alphani/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_fe026_row9_col1" class="data row9 col1" >/home/alphani/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_fe026_row10_col1" class="data row10 col1" >/home/alphani/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_fe026_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_fe026_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/alphani/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_fe026_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_fe026_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_fe026_row15_col1" class="data row15 col1" >/home/alphani/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_fe026_row16_col1" class="data row16 col1" >1.7.4</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_fe026_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_fe026_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_fe026_row18_col1" class="data row18 col1" >distributed data streaming for scientific data analytics</td>
#     </tr>
#   </tbody>
# </table>

# %%
slice_name= "Testbed-openvswitch-2"

sites = [site1] = fablib.get_random_sites(count=1)
print(f"Sites: {sites}")

site_node_count = 2
bridge1_name = 'bridge1'
bridge2_name = 'bridge2'
# Out:
# Sites: ['GPN']

# %%
slice = fablib.new_slice(name=slice_name)
default_image= 'default_ubuntu_22'

# %%
bridge1 = slice.add_node(name=bridge1_name, site=site1, cores=2, ram=8, disk=10, image=default_image, host=f"{site1.lower()}-w1.fabric-testbed.net")
bridge1_nic1 = bridge1.add_component(model='NIC_Basic', name='nic_local_1')
bridge1_nic2 = bridge1.add_component(model='NIC_Basic', name='nic_local_2')
bridge1_nic3 = bridge1.add_component(model='NIC_Basic', name='nic_local_3')

bridge2 = slice.add_node(name=bridge2_name, site=site1, cores=2, ram=8, disk=10, image=default_image, host=f"{site1.lower()}-w1.fabric-testbed.net")
bridge2_nic1 = bridge2.add_component(model='NIC_Basic', name='nic_local_1')
bridge2_nic2 = bridge2.add_component(model='NIC_Basic', name='nic_local_2')
bridge2_nic3 = bridge2.add_component(model='NIC_Basic', name='nic_local_3')

# %% [markdown]
# ### Connecting bridges nodes

# %%
net = slice.add_l2network(name=f'net-br1-br2')
net.add_interface(bridge1.get_interfaces()[2])
net.add_interface(bridge2.get_interfaces()[2])

# %% [markdown]
# ### Adding Nodes to bridge 1

# %%
for br_num in range(2):
    print(f"Adding nodes to {site1}-bridge{br_num+1}")
    for node_num in range(site_node_count):
        node_name = f"{site1.lower()}-bridge{br_num}-{node_num+1}"
        node = slice.add_node(name=node_name, site=site1, cores=2, ram=8, disk=10, image=default_image, host=f"{site1.lower()}-w2.fabric-testbed.net")
        iface = node.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]    
        net = slice.add_l2network(name=f"net-br{br_num}-{node_num+1}")
        net.add_interface(iface)

        if br_num%2==0:
            net.add_interface(bridge1.get_interfaces()[node_num])
        else:
            net.add_interface(bridge2.get_interfaces()[node_num])
# Out:
# Adding nodes to GPN-bridge1
# Adding nodes to GPN-bridge2

# %%
slice.submit();
# Out:
# Retry: 11, Time: 325 sec
# <style type="text/css">
# #T_22430 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_22430 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_22430 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_22430_row0_col0, #T_22430_row0_col1, #T_22430_row1_col0, #T_22430_row1_col1, #T_22430_row2_col0, #T_22430_row2_col1, #T_22430_row3_col0, #T_22430_row3_col1, #T_22430_row4_col0, #T_22430_row4_col1, #T_22430_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_22430_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_22430">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_22430_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_22430_row0_col1" class="data row0 col1" >eb7d7d3f-f2e2-4f6b-b762-64c9937677c7</td>
#     </tr>
#     <tr>
#       <td id="T_22430_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_22430_row1_col1" class="data row1 col1" >Testbed-openvswitch-2</td>
#     </tr>
#     <tr>
#       <td id="T_22430_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_22430_row2_col1" class="data row2 col1" >2025-01-04 16:35:11 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_22430_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_22430_row3_col1" class="data row3 col1" >2025-01-03 16:35:11 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_22430_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_22430_row4_col1" class="data row4 col1" >220c2d8a-ae05-465a-a98b-8178415e1b30</td>
#     </tr>
#     <tr>
#       <td id="T_22430_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_22430_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0a89d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0a89d th {
#   text-align: left;
# }
# #T_0a89d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0a89d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0a89d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0a89d_row0_col0, #T_0a89d_row0_col1, #T_0a89d_row0_col2, #T_0a89d_row0_col3, #T_0a89d_row0_col4, #T_0a89d_row0_col5, #T_0a89d_row0_col6, #T_0a89d_row0_col7, #T_0a89d_row0_col8, #T_0a89d_row0_col9, #T_0a89d_row0_col10, #T_0a89d_row0_col13, #T_0a89d_row0_col14, #T_0a89d_row0_col15, #T_0a89d_row1_col0, #T_0a89d_row1_col1, #T_0a89d_row1_col2, #T_0a89d_row1_col3, #T_0a89d_row1_col4, #T_0a89d_row1_col5, #T_0a89d_row1_col6, #T_0a89d_row1_col7, #T_0a89d_row1_col8, #T_0a89d_row1_col9, #T_0a89d_row1_col10, #T_0a89d_row1_col13, #T_0a89d_row1_col14, #T_0a89d_row1_col15, #T_0a89d_row2_col0, #T_0a89d_row2_col1, #T_0a89d_row2_col2, #T_0a89d_row2_col3, #T_0a89d_row2_col4, #T_0a89d_row2_col5, #T_0a89d_row2_col6, #T_0a89d_row2_col7, #T_0a89d_row2_col8, #T_0a89d_row2_col9, #T_0a89d_row2_col10, #T_0a89d_row2_col13, #T_0a89d_row2_col14, #T_0a89d_row2_col15, #T_0a89d_row3_col0, #T_0a89d_row3_col1, #T_0a89d_row3_col2, #T_0a89d_row3_col3, #T_0a89d_row3_col4, #T_0a89d_row3_col5, #T_0a89d_row3_col6, #T_0a89d_row3_col7, #T_0a89d_row3_col8, #T_0a89d_row3_col9, #T_0a89d_row3_col10, #T_0a89d_row3_col13, #T_0a89d_row3_col14, #T_0a89d_row3_col15, #T_0a89d_row4_col0, #T_0a89d_row4_col1, #T_0a89d_row4_col2, #T_0a89d_row4_col3, #T_0a89d_row4_col4, #T_0a89d_row4_col5, #T_0a89d_row4_col6, #T_0a89d_row4_col7, #T_0a89d_row4_col8, #T_0a89d_row4_col9, #T_0a89d_row4_col10, #T_0a89d_row4_col13, #T_0a89d_row4_col14, #T_0a89d_row4_col15, #T_0a89d_row5_col0, #T_0a89d_row5_col1, #T_0a89d_row5_col2, #T_0a89d_row5_col3, #T_0a89d_row5_col4, #T_0a89d_row5_col5, #T_0a89d_row5_col6, #T_0a89d_row5_col7, #T_0a89d_row5_col8, #T_0a89d_row5_col9, #T_0a89d_row5_col10, #T_0a89d_row5_col13, #T_0a89d_row5_col14, #T_0a89d_row5_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_0a89d_row0_col11, #T_0a89d_row1_col11, #T_0a89d_row2_col11, #T_0a89d_row3_col11, #T_0a89d_row4_col11, #T_0a89d_row5_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_0a89d_row0_col12, #T_0a89d_row1_col12, #T_0a89d_row2_col12, #T_0a89d_row3_col12, #T_0a89d_row4_col12, #T_0a89d_row5_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_0a89d">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_0a89d_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_0a89d_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_0a89d_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_0a89d_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_0a89d_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_0a89d_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_0a89d_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_0a89d_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_0a89d_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_0a89d_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_0a89d_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_0a89d_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_0a89d_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_0a89d_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_0a89d_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_0a89d_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0a89d_row0_col0" class="data row0 col0" >fba723b5-d8ba-4a9b-9a47-06cbf2b198a9</td>
#       <td id="T_0a89d_row0_col1" class="data row0 col1" >bridge1</td>
#       <td id="T_0a89d_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_0a89d_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_0a89d_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_0a89d_row0_col5" class="data row0 col5" >default_ubuntu_22</td>
#       <td id="T_0a89d_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_0a89d_row0_col7" class="data row0 col7" >gpn-w1.fabric-testbed.net</td>
#       <td id="T_0a89d_row0_col8" class="data row0 col8" >GPN</td>
#       <td id="T_0a89d_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_0a89d_row0_col10" class="data row0 col10" >2610:e0:a04c:fab2:f816:3eff:fe9c:950e</td>
#       <td id="T_0a89d_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_0a89d_row0_col12" class="data row0 col12" ></td>
#       <td id="T_0a89d_row0_col13" class="data row0 col13" >ssh -i /home/alphani/work/fabric_config/slice_key -F /home/alphani/work/fabric_config/ssh_config ubuntu@2610:e0:a04c:fab2:f816:3eff:fe9c:950e</td>
#       <td id="T_0a89d_row0_col14" class="data row0 col14" >/home/alphani/work/fabric_config/slice_key.pub</td>
#       <td id="T_0a89d_row0_col15" class="data row0 col15" >/home/alphani/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0a89d_row1_col0" class="data row1 col0" >e0bb2a4e-2adc-4d80-b205-408e819389b1</td>
#       <td id="T_0a89d_row1_col1" class="data row1 col1" >bridge2</td>
#       <td id="T_0a89d_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_0a89d_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_0a89d_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_0a89d_row1_col5" class="data row1 col5" >default_ubuntu_22</td>
#       <td id="T_0a89d_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_0a89d_row1_col7" class="data row1 col7" >gpn-w1.fabric-testbed.net</td>
#       <td id="T_0a89d_row1_col8" class="data row1 col8" >GPN</td>
#       <td id="T_0a89d_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_0a89d_row1_col10" class="data row1 col10" >2610:e0:a04c:fab2:f816:3eff:fe82:2abb</td>
#       <td id="T_0a89d_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_0a89d_row1_col12" class="data row1 col12" ></td>
#       <td id="T_0a89d_row1_col13" class="data row1 col13" >ssh -i /home/alphani/work/fabric_config/slice_key -F /home/alphani/work/fabric_config/ssh_config ubuntu@2610:e0:a04c:fab2:f816:3eff:fe82:2abb</td>
#       <td id="T_0a89d_row1_col14" class="data row1 col14" >/home/alphani/work/fabric_config/slice_key.pub</td>
#       <td id="T_0a89d_row1_col15" class="data row1 col15" >/home/alphani/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0a89d_row2_col0" class="data row2 col0" >971c5357-93f7-4b8f-81ff-e29db3deadec</td>
#       <td id="T_0a89d_row2_col1" class="data row2 col1" >gpn-bridge0-1</td>
#       <td id="T_0a89d_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_0a89d_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_0a89d_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_0a89d_row2_col5" class="data row2 col5" >default_ubuntu_22</td>
#       <td id="T_0a89d_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_0a89d_row2_col7" class="data row2 col7" >gpn-w2.fabric-testbed.net</td>
#       <td id="T_0a89d_row2_col8" class="data row2 col8" >GPN</td>
#       <td id="T_0a89d_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_0a89d_row2_col10" class="data row2 col10" >2610:e0:a04c:fab2:f816:3eff:feec:bde9</td>
#       <td id="T_0a89d_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_0a89d_row2_col12" class="data row2 col12" ></td>
#       <td id="T_0a89d_row2_col13" class="data row2 col13" >ssh -i /home/alphani/work/fabric_config/slice_key -F /home
# <style type="text/css">
# #T_0974f caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0974f th {
#   text-align: left;
# }
# #T_0974f tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0974f tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0974f .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0974f_row0_col0, #T_0974f_row0_col1, #T_0974f_row0_col2, #T_0974f_row0_col3, #T_0974f_row0_col4, #T_0974f_row0_col5, #T_0974f_row0_col6, #T_0974f_row1_col0, #T_0974f_row1_col1, #T_0974f_row1_col2, #T_0974f_row1_col3, #T_0974f_row1_col4, #T_0974f_row1_col5, #T_0974f_row1_col6, #T_0974f_row2_col0, #T_0974f_row2_col1, #T_0974f_row2_col2, #T_0974f_row2_col3, #T_0974f_row2_col4, #T_0974f_row2_col5, #T_0974f_row2_col6, #T_0974f_row3_col0, #T_0974f_row3_col1, #T_0974f_row3_col2, #T_0974f_row3_col3, #T_0974f_row3_col4, #T_0974f_row3_col5, #T_0974f_row3_col6, #T_0974f_row4_col0, #T_0974f_row4_col1, #T_0974f_row4_col2, #T_0974f_row4_col3, #T_0974f_row4_col4, #T_0974f_row4_col5, #T_0974f_row4_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_0974f_row0_col7, #T_0974f_row1_col7, #T_0974f_row2_col7, #T_0974f_row3_col7, #T_0974f_row4_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_0974f_row0_col8, #T_0974f_row1_col8, #T_0974f_row2_col8, #T_0974f_row3_col8, #T_0974f_row4_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_0974f">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_0974f_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_0974f_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_0974f_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_0974f_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_0974f_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_0974f_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_0974f_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_0974f_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_0974f_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0974f_row0_col0" class="data row0 col0" >b0674d8b-a11f-4211-978a-766f8755c845</td>
#       <td id="T_0974f_row0_col1" class="data row0 col1" >net-br0-1</td>
#       <td id="T_0974f_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_0974f_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_0974f_row0_col4" class="data row0 col4" >GPN</td>
#       <td id="T_0974f_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_0974f_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_0974f_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_0974f_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_0974f_row1_col0" class="data row1 col0" >6bb81042-8c28-4f10-9d67-27afe579a192</td>
#       <td id="T_0974f_row1_col1" class="data row1 col1" >net-br0-2</td>
#       <td id="T_0974f_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_0974f_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_0974f_row1_col4" class="data row1 col4" >GPN</td>
#       <td id="T_0974f_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_0974f_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_0974f_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_0974f_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_0974f_row2_col0" class="data row2 col0" >66fbd0b9-14d0-4bbc-a4a3-e27de4129d70</td>
#       <td id="T_0974f_row2_col1" class="data row2 col1" >net-br1-1</td>
#       <td id="T_0974f_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_0974f_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_0974f_row2_col4" class="data row2 col4" >GPN</td>
#       <td id="T_0974f_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_0974f_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_0974f_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_0974f_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_0974f_row3_col0" class="data row3 col0" >4030eb84-f5fe-424c-9350-d9f01d0353ab</td>
#       <td id="T_0974f_row3_col1" class="data row3 col1" >net-br1-2</td>
#       <td id="T_0974f_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_0974f_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_0974f_row3_col4" class="data row3 col4" >GPN</td>
#       <td id="T_0974f_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_0974f_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_0974f_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_0974f_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_0974f_row4_col0" class="data row4 col0" >85da2148-9988-4270-bcfc-56e49bd58d2c</td>
#       <td id="T_0974f_row4_col1" class="data row4 col1" >net-br1-br2</td>
#       <td id="T_0974f_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_0974f_row4_col3" class="data row4 col3" >L2Bridge</td>
#       <td id="T_0974f_row4_col4" class="data row4 col4" >GPN</td>
#       <td id="T_0974f_row4_col5" class="data row4 col5" >None</td>
#       <td id="T_0974f_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_0974f_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_0974f_row4_col8" class="data row4 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_87414 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_87414 th {
#   text-align: left;
# }
# #T_87414 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_87414 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_87414 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_87414_row0_col0, #T_87414_row0_col1, #T_87414_row0_col2, #T_87414_row0_col3, #T_87414_row0_col4, #T_87414_row0_col5, #T_87414_row0_col6, #T_87414_row0_col7, #T_87414_row0_col8, #T_87414_row0_col9, #T_87414_row0_col10, #T_87414_row0_col11, #T_87414_row0_col12, #T_87414_row1_col0, #T_87414_row1_col1, #T_87414_row1_col2, #T_87414_row1_col3, #T_87414_row1_col4, #T_87414_row1_col5, #T_87414_row1_col6, #T_87414_row1_col7, #T_87414_row1_col8, #T_87414_row1_col9, #T_87414_row1_col10, #T_87414_row1_col11, #T_87414_row1_col12, #T_87414_row2_col0, #T_87414_row2_col1, #T_87414_row2_col2, #T_87414_row2_col3, #T_87414_row2_col4, #T_87414_row2_col5, #T_87414_row2_col6, #T_87414_row2_col7, #T_87414_row2_col8, #T_87414_row2_col9, #T_87414_row2_col10, #T_87414_row2_col11, #T_87414_row2_col12, #T_87414_row3_col0, #T_87414_row3_col1, #T_87414_row3_col2, #T_87414_row3_col3, #T_87414_row3_col4, #T_87414_row3_col5, #T_87414_row3_col6, #T_87414_row3_col7, #T_87414_row3_col8, #T_87414_row3_col9, #T_87414_row3_col10, #T_87414_row3_col11, #T_87414_row3_col12, #T_87414_row4_col0, #T_87414_row4_col1, #T_87414_row4_col2, #T_87414_row4_col3, #T_87414_row4_col4, #T_87414_row4_col5, #T_87414_row4_col6, #T_87414_row4_col7, #T_87414_row4_col8, #T_87414_row4_col9, #T_87414_row4_col10, #T_87414_row4_col11, #T_87414_row4_col12, #T_87414_row5_col0, #T_87414_row5_col1, #T_87414_row5_col2, #T_87414_row5_col3, #T_87414_row5_col4, #T_87414_row5_col5, #T_87414_row5_col6, #T_87414_row5_col7, #T_87414_row5_col8, #T_87414_row5_col9, #T_87414_row5_col10, #T_87414_row5_col11, #T_87414_row5_col12, #T_87414_row6_col0, #T_87414_row6_col1, #T_87414_row6_col2, #T_87414_row6_col3, #T_87414_row6_col4, #T_87414_row6_col5, #T_87414_row6_col6, #T_87414_row6_col7, #T_87414_row6_col8, #T_87414_row6_col9, #T_87414_row6_col10, #T_87414_row6_col11, #T_87414_row6_col12, #T_87414_row7_col0, #T_87414_row7_col1, #T_87414_row7_col2, #T_87414_row7_col3, #T_87414_row7_col4, #T_87414_row7_col5, #T_87414_row7_col6, #T_87414_row7_col7, #T_87414_row7_col8, #T_87414_row7_col9, #T_87414_row7_col10, #T_87414_row7_col11, #T_87414_row7_col12, #T_87414_row8_col0, #T_87414_row8_col1, #T_87414_row8_col2, #T_87414_row8_col3, #T_87414_row8_col4, #T_87414_row8_col5, #T_87414_row8_col6, #T_87414_row8_col7, #T_87414_row8_col8, #T_87414_row8_col9, #T_87414_row8_col10, #T_87414_row8_col11, #T_87414_row8_col12, #T_87414_row9_col0, #T_87414_row9_col1, #T_87414_row9_col2, #T_87414_row9_col3, #T_87414_row9_col4, #T_87414_row9_col5, #T_87414_row9_col6, #T_87414_row9_col7, #T_87414_row9_col8, #T_87414_row9_col9, #T_87414_row9_col10, #T_87414_row9_col11, #T_87414_row9_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_87414">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_87414_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_87414_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_87414_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_87414_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_87414_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_87414_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_87414_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_87414_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_87414_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_87414_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_87414_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_87414_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_87414_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87414_row0_col0" class="data row0 col0" >bridge1-nic_local_3-p1</td>
#       <td id="T_87414_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_87414_row0_col2" class="data row0 col2" >bridge1</td>
#       <td id="T_87414_row0_col3" class="data row0 col3" >net-br0-1</td>
#       <td id="T_87414_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_87414_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_87414_row0_col6" class="data row0 col6" ></td>
#       <td id="T_87414_row0_col7" class="data row0 col7" >06:7E:61:21:AF:20</td>
#       <td id="T_87414_row0_col8" class="data row0 col8" >enp9s0</td>
#       <td id="T_87414_row0_col9" class="data row0 col9" >enp9s0</td>
#       <td id="T_87414_row0_col10" class="data row0 col10" >fe80::47e:61ff:fe21:af20</td>
#       <td id="T_87414_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_87414_row0_col12" class="data row0 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_87414_row1_col0" class="data row1 col0" >bridge1-nic_local_1-p1</td>
#       <td id="T_87414_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_87414_row1_col2" class="data row1 col2" >bridge1</td>
#       <td id="T_87414_row1_col3" class="data row1 col3" >net-br0-2</td>
#       <td id="T_87414_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_87414_row1_col5" class="data row1 col5" >config</td>
#       <td id="T_87414_row1_col6" class="data row1 col6" ></td>
#       <td id="T_87414_row1_col7" class="data row1 col7" >02:19:1B:38:14:52</td>
#       <td id="T_87414_row1_col8" class="data row1 col8" >enp7s0</td>
#       <td id="T_87414_row1_col9" class="data row1 col9" >enp7s0</td>
#       <td id="T_87414_row1_col10" class="data row1 col10" >fe80::19:1bff:fe38:1452</td>
#       <td id="T_87414_row1_col11" class="data row1 col11" >6</td>
#       <td id="T_87414_row1_col12" class="data row1 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_87414_row2_col0" class="data row2 col0" >bridge1-nic_local_2-p1</td>
#       <td id="T_87414_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_87414_row2_col2" class="data row2 col2" >bridge1</td>
#       <td id="T_87414_row2_col3" class="data row2 col3" >net-br1-br2</td>
#       <td id="T_87414_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_87414_row2_col5" class="data row2 col5" >config</td>
#       <td id="T_87414_row2_col6" class="data row2 col6" ></td>
#       <td id="T_87414_row2_col7" class="data row2 col7" >02:31:E6:AF:DC:68</td>
#       <td id="T_87414_row2_col8" class="data row2 col8" >enp8s0</td>
#       <td id="T_87414_row2_col9" class="data row2 col9" >enp8s0</td>
#       <td id="T_87414_row2_col10" class="data row2 col10" >fe80::31:e6ff:feaf:dc68</td>
#       <td id="T_87414_row2_col11" class="data row2 col11" >6</td>
#       <td id="T_87414_row2_col12" class="data row2 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_87414_row3_col0" class="data row3 col0" >bridge2-nic_local_2-p1</td>
#       <td id="T_87414_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_87414_row3_col2" class="data row3 col2" >bridge2</td>
#       <td id="T_87414_row3_col3" class="data row3 col3" >net-br1-br2</td>
#       <td id="T_87414_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_87414_row3_col5" class="data row3 col5" >config</td>
#       <td id="T_87414_row3_col6" class="data row3 col6" ></td>
#       <td id="T_87414_row3_col7" class="data row3 col7" >06:96:8A:E0:E7:8D</td>
#       <td id="T_87414_row3_col8" class="data row3 col8" >enp7s0</td>
#       <td id="T_87414_row3_col9" class="data row3 col9" >enp7s0</td>
#       <td id="T_87414_row3_col10" class="data row3 col10" >fe80::496:8aff:fee0:e78d</td>
#       <td id="T_8741
# Time to print interfaces 353 seconds

# %% [markdown]
# # OVS

# %%
try:
    for node in slice.get_nodes():
        if node.get_name().startswith("bridge"):
            stdout, stderr = node.execute('yes | sudo apt-get -y update && sudo apt-get upgrade', quiet=True) 
            stdout, stderr = node.execute('yes | sudo apt-get -y install openvswitch-switch openvswitch-common', quiet=True)
            stdout, stderr = node.execute('sudo apt-get -y install net-tools', quiet=True)
            print(f"done bridge: {node.get_name()}")
    print("Done")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# done bridge: bridge1
# done bridge: bridge2
# Done

# %%
bridge1 = slice.get_node(name=bridge1_name)
stdout, stderr = bridge1.execute('sudo ovs-vsctl add-br br0')
for interface in bridge1.get_interfaces():
    stdout, stderr = bridge1.execute(f'sudo ovs-vsctl add-port br0 {interface.get_physical_os_interface_name()}')
    #Remove IP addresses for all interfaces
    stdout, stderr = bridge1.execute(f'sudo ifconfig {interface.get_physical_os_interface_name()} 0')
    
#bring the bridge up
stdout, stderr = bridge1.execute('sudo ifconfig br0 up')

print("Done")
stdout, stderr = bridge1.execute('sudo ovs-vsctl set bridge br0 stp_enable=true')
stdout, stderr = bridge1.execute('sudo ovs-appctl stp/show')
# Out:
# Done
# ---- br0 ----
# Root ID:
#   stp-priority  32768
#   stp-system-id   32:ee:63:98:71:44
#   stp-hello-time  2s
#   stp-max-age     20s
#   stp-fwd-delay   15s
#   This bridge is the root
#
# Bridge ID:
#   stp-priority  32768
#   stp-system-id   32:ee:63:98:71:44
#   stp-hello-time  2s
#   stp-max-age     20s
#   stp-fwd-delay   15s
#
#   Interface  Role       State      Cost  Pri.Nbr
#   ---------- ---------- ---------- ----- -------
#   enp8s0     designated listening  2     128.1
#   enp7s0     designated listening  2     128.2
#   enp9s0     designated listening  2     128.3

# %%
bridge2 = slice.get_node(name=bridge2_name)
stdout, stderr = bridge2.execute('sudo ovs-vsctl add-br br0')
for interface in bridge2.get_interfaces():
    stdout, stderr = bridge2.execute(f'sudo ovs-vsctl add-port br0 {interface.get_physical_os_interface_name()}')
    #Remove IP addresses for all interfaces
    stdout, stderr = bridge2.execute(f'sudo ifconfig {interface.get_physical_os_interface_name()} 0')
    
#bring the bridge up
stdout, stderr = bridge2.execute('sudo ifconfig br0 up')

print("Done")
stdout, stderr = bridge2.execute('sudo ovs-vsctl set bridge br0 stp_enable=true')
stdout, stderr = bridge2.execute('sudo ovs-appctl stp/show')
# Out:
# Done
# ---- br0 ----
# Root ID:
#   stp-priority  32768
#   stp-system-id   2a:63:96:a6:75:4d
#   stp-hello-time  2s
#   stp-max-age     20s
#   stp-fwd-delay   15s
#   This bridge is the root
#
# Bridge ID:
#   stp-priority  32768
#   stp-system-id   2a:63:96:a6:75:4d
#   stp-hello-time  2s
#   stp-max-age     20s
#   stp-fwd-delay   15s
#
#   Interface  Role       State      Cost  Pri.Nbr
#   ---------- ---------- ---------- ----- -------
#   enp8s0     designated listening  2     128.1
#   enp7s0     designated listening  2     128.2
#   enp9s0     designated listening  2     128.3

# %% [markdown]
# # Host Setup

# %%
networks = [
    "10.10.10.1/24",
    "10.10.10.2/24",
    "10.10.10.3/24",
    "10.10.10.4/24"
]

for br_num in range(2):
    for i in range(2):
        host = slice.get_node(name=f'{site1.lower()}-bridge{br_num}-{i+1}')
        stdout, stderr = host.execute('sudo apt-get -y install net-tools', quiet=True)
        stdout, stderr = host.execute(f'sudo ip link set dev {host.get_interfaces()[0].get_physical_os_interface_name()} up', quiet=True)
        stdout, stderr = host.execute(f'sudo ip addr add {networks[i+2*br_num]} dev {host.get_interfaces()[0].get_physical_os_interface_name()}', quiet=True)

# %%
host1 = slice.get_node(name=f'{site1.lower()}-bridge0-1')
stdout, stderr = host1.execute('ping 10.10.10.2 -c 5')
# Out:
# PING 10.10.10.2 (10.10.10.2) 56(84) bytes of data.
# 64 bytes from 10.10.10.2: icmp_seq=1 ttl=64 time=0.288 ms
# 64 bytes from 10.10.10.2: icmp_seq=2 ttl=64 time=0.166 ms
# 64 bytes from 10.10.10.2: icmp_seq=3 ttl=64 time=0.279 ms
# 64 bytes from 10.10.10.2: icmp_seq=4 ttl=64 time=0.147 ms
# 64 bytes from 10.10.10.2: icmp_seq=5 ttl=64 time=0.121 ms
#
# --- 10.10.10.2 ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4100ms
# rtt min/avg/max/mdev = 0.121/0.200/0.288/0.069 ms

# %%
stdout, stderr = host1.execute('ping 10.10.10.3 -c 5')
# Out:
# PING 10.10.10.3 (10.10.10.3) 56(84) bytes of data.
# 64 bytes from 10.10.10.3: icmp_seq=1 ttl=64 time=1.10 ms
# 64 bytes from 10.10.10.3: icmp_seq=2 ttl=64 time=0.182 ms
# 64 bytes from 10.10.10.3: icmp_seq=3 ttl=64 time=0.171 ms
# 64 bytes from 10.10.10.3: icmp_seq=4 ttl=64 time=0.164 ms
# 64 bytes from 10.10.10.3: icmp_seq=5 ttl=64 time=0.254 ms
#
# --- 10.10.10.3 ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4053ms
# rtt min/avg/max/mdev = 0.164/0.374/1.099/0.363 ms

# %%
stdout, stderr = host1.execute('ping 10.10.10.4 -c 5')
# Out:
# PING 10.10.10.4 (10.10.10.4) 56(84) bytes of data.
# 64 bytes from 10.10.10.4: icmp_seq=1 ttl=64 time=0.804 ms
# 64 bytes from 10.10.10.4: icmp_seq=2 ttl=64 time=0.242 ms
# 64 bytes from 10.10.10.4: icmp_seq=3 ttl=64 time=0.168 ms
# 64 bytes from 10.10.10.4: icmp_seq=4 ttl=64 time=0.181 ms
# 64 bytes from 10.10.10.4: icmp_seq=5 ttl=64 time=0.167 ms
#
# --- 10.10.10.4 ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4074ms
# rtt min/avg/max/mdev = 0.167/0.312/0.804/0.247 ms

# %%
slice.delete()
