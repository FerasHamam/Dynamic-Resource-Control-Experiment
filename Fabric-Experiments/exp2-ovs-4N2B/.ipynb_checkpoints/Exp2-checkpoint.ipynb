# %% [markdown]
# # Experiment #1: Open vSwitch 4 Networks

# %% [markdown]
# In this experiment we try to connect 4 networks with different hosts together with a bridge in the middle. We will be using Open vSwitch for the bridge, alternate solutions are Linux Bridge and Behavioral Model (BMv2).

# %% [markdown]
# ## References
# - [Open vSwitch Example](https://github.com/fabric-testbed/jupyter-examples/blob/main/fabric_examples/complex_recipes/openvswitch/openvswitch.ipynb)
# - [BMv4](https://github.com/p4lang/behavioral-model)

# %% [markdown]
# ## TODO's
#
# - Add Open vSwitch flow configuratation on ports and so on.
# - Add tools on how to track packets in the bridge.
# - measure of congestion.

# %% [markdown]
# ## Topology

# %% [markdown]
# <img src="./fig/Testbed-openvswitch-1.png" width=40%>

# %% [markdown]
# ## Code

# %%
from ipaddress import ip_address, IPv4Address, IPv4Network
import ipaddress
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager


fablib = fablib_manager()
fablib.show_config();
# Out:
# <style type="text/css">
# #T_819aa tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_819aa tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_819aa caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_819aa_row0_col0, #T_819aa_row0_col1, #T_819aa_row1_col0, #T_819aa_row1_col1, #T_819aa_row2_col0, #T_819aa_row2_col1, #T_819aa_row3_col0, #T_819aa_row3_col1, #T_819aa_row4_col0, #T_819aa_row4_col1, #T_819aa_row5_col0, #T_819aa_row5_col1, #T_819aa_row6_col0, #T_819aa_row6_col1, #T_819aa_row7_col0, #T_819aa_row7_col1, #T_819aa_row8_col0, #T_819aa_row8_col1, #T_819aa_row9_col0, #T_819aa_row9_col1, #T_819aa_row10_col0, #T_819aa_row10_col1, #T_819aa_row11_col0, #T_819aa_row11_col1, #T_819aa_row12_col0, #T_819aa_row12_col1, #T_819aa_row13_col0, #T_819aa_row13_col1, #T_819aa_row14_col0, #T_819aa_row14_col1, #T_819aa_row15_col0, #T_819aa_row15_col1, #T_819aa_row16_col0, #T_819aa_row16_col1, #T_819aa_row17_col0, #T_819aa_row17_col1, #T_819aa_row18_col0, #T_819aa_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_819aa">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_819aa_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_819aa_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_819aa_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_819aa_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_819aa_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_819aa_row4_col1" class="data row4 col1" >/home/alphani/.fabric_token.json</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_819aa_row5_col1" class="data row5 col1" >220c2d8a-ae05-465a-a98b-8178415e1b30</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_819aa_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_819aa_row7_col1" class="data row7 col1" >sa2994_0000240697</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_819aa_row8_col1" class="data row8 col1" >/home/alphani/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_819aa_row9_col1" class="data row9 col1" >/home/alphani/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_819aa_row10_col1" class="data row10 col1" >/home/alphani/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_819aa_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_819aa_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/alphani/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_819aa_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_819aa_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_819aa_row15_col1" class="data row15 col1" >/home/alphani/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_819aa_row16_col1" class="data row16 col1" >1.7.4</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_819aa_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_819aa_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_819aa_row18_col1" class="data row18 col1" >distributed data streaming for scientific data analytics</td>
#     </tr>
#   </tbody>
# </table>

# %%
slice_name= "Testbed-openvswitch-1"

sites = [site1] = fablib.get_random_sites(count=1)
print(f"Sites: {sites}")

site_node_count = 4
bridge1_name = 'bridge1'
# Out:
# Sites: ['NEWY']

# %%
slice = fablib.new_slice(name=slice_name)
default_image= 'default_ubuntu_22'

# %%
bridge1 = slice.add_node(name=bridge1_name, site=site1, cores=2, ram=8, disk=10, image=default_image, host=f"{site1.lower()}-w1.fabric-testbed.net")
bridge1_nic1 = bridge1.add_component(model='NIC_Basic', name='nic_local_1')
bridge1_nic2 = bridge1.add_component(model='NIC_Basic', name='nic_local_2')
bridge1_nic3 = bridge1.add_component(model='NIC_Basic', name='nic_local_3')
bridge1_nic4 = bridge1.add_component(model='NIC_Basic', name='nic_local_4')

# %%
i = 0
print(f"Adding nodes to {site1}")
for node_num in range(site_node_count):
    node_name = f"{site1.lower()}{node_num+1}"
    
    node = slice.add_node(name=node_name, site=site1, cores=2, ram=8, disk=10, image=default_image, host=f"{site1.lower()}-w2.fabric-testbed.net")
    iface = node.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]    
    net = slice.add_l2network(name=f"net{node_num}")

    net.add_interface(iface)
    net.add_interface(bridge1.get_interfaces()[i])
    i += 1
# Out:
# Adding nodes to NEWY

# %%
slice.submit();
# Out:
# Retry: 11, Time: 318 sec
# <style type="text/css">
# #T_d3db7 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_d3db7 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d3db7 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_d3db7_row0_col0, #T_d3db7_row0_col1, #T_d3db7_row1_col0, #T_d3db7_row1_col1, #T_d3db7_row2_col0, #T_d3db7_row2_col1, #T_d3db7_row3_col0, #T_d3db7_row3_col1, #T_d3db7_row4_col0, #T_d3db7_row4_col1, #T_d3db7_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_d3db7_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_d3db7">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d3db7_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_d3db7_row0_col1" class="data row0 col1" >83bf97fc-7aa9-4b7d-a0ae-1cd7a7d352ec</td>
#     </tr>
#     <tr>
#       <td id="T_d3db7_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_d3db7_row1_col1" class="data row1 col1" >Testbed-openvswitch-1</td>
#     </tr>
#     <tr>
#       <td id="T_d3db7_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_d3db7_row2_col1" class="data row2 col1" >2025-01-03 23:17:54 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_d3db7_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_d3db7_row3_col1" class="data row3 col1" >2025-01-02 23:17:54 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_d3db7_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_d3db7_row4_col1" class="data row4 col1" >220c2d8a-ae05-465a-a98b-8178415e1b30</td>
#     </tr>
#     <tr>
#       <td id="T_d3db7_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_d3db7_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9aa73 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_9aa73 th {
#   text-align: left;
# }
# #T_9aa73 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9aa73 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_9aa73 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9aa73_row0_col0, #T_9aa73_row0_col1, #T_9aa73_row0_col2, #T_9aa73_row0_col3, #T_9aa73_row0_col4, #T_9aa73_row0_col5, #T_9aa73_row0_col6, #T_9aa73_row0_col7, #T_9aa73_row0_col8, #T_9aa73_row0_col9, #T_9aa73_row0_col10, #T_9aa73_row0_col13, #T_9aa73_row0_col14, #T_9aa73_row0_col15, #T_9aa73_row1_col0, #T_9aa73_row1_col1, #T_9aa73_row1_col2, #T_9aa73_row1_col3, #T_9aa73_row1_col4, #T_9aa73_row1_col5, #T_9aa73_row1_col6, #T_9aa73_row1_col7, #T_9aa73_row1_col8, #T_9aa73_row1_col9, #T_9aa73_row1_col10, #T_9aa73_row1_col13, #T_9aa73_row1_col14, #T_9aa73_row1_col15, #T_9aa73_row2_col0, #T_9aa73_row2_col1, #T_9aa73_row2_col2, #T_9aa73_row2_col3, #T_9aa73_row2_col4, #T_9aa73_row2_col5, #T_9aa73_row2_col6, #T_9aa73_row2_col7, #T_9aa73_row2_col8, #T_9aa73_row2_col9, #T_9aa73_row2_col10, #T_9aa73_row2_col13, #T_9aa73_row2_col14, #T_9aa73_row2_col15, #T_9aa73_row3_col0, #T_9aa73_row3_col1, #T_9aa73_row3_col2, #T_9aa73_row3_col3, #T_9aa73_row3_col4, #T_9aa73_row3_col5, #T_9aa73_row3_col6, #T_9aa73_row3_col7, #T_9aa73_row3_col8, #T_9aa73_row3_col9, #T_9aa73_row3_col10, #T_9aa73_row3_col13, #T_9aa73_row3_col14, #T_9aa73_
.level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_610b4_row0_col0, #T_610b4_row0_col1, #T_610b4_row0_col2, #T_610b4_row0_col3, #T_610b4_row0_col4, #T_610b4_row0_col5, #T_610b4_row0_col6, #T_610b4_row0_col7, #T_610b4_row0_col8, #T_610b4_row0_col9, #T_610b4_row0_col10, #T_610b4_row0_col11, #T_610b4_row0_col12, #T_610b4_row1_col0, #T_610b4_row1_col1, #T_610b4_row1_col2, #T_610b4_row1_col3, #T_610b4_row1_col4, #T_610b4_row1_col5, #T_610b4_row1_col6, #T_610b4_row1_col7, #T_610b4_row1_col8, #T_610b4_row1_col9, #T_610b4_row1_col10, #T_610b4_row1_col11, #T_610b4_row1_col12, #T_610b4_row2_col0, #T_610b4_row2_col1, #T_610b4_row2_col2, #T_610b4_row2_col3, #T_610b4_row2_col4, #T_610b4_row2_col5, #T_610b4_row2_col6, #T_610b4_row2_col7, #T_610b4_row2_col8, #T_610b4_row2_col9, #T_610b4_row2_col10, #T_610b4_row2_col11, #T_610b4_row2_col12, #T_610b4_row3_col0, #T_610b4_row3_col1, #T_610b4_row3_col2, #T_610b4_row3_col3, #T_610b4_row3_col4, #T_610b4_row3_col5, #T_610b4_row3_col6, #T_610b4_row3_col7, #T_610b4_row3_col8, #T_610b4_row3_col9, #T_610b4_row3_col10, #T_610b4_row3_col11, #T_610b4_row3_col12, #T_610b4_row4_col0, #T_610b4_row4_col1, #T_610b4_row4_col2, #T_610b4_row4_col3, #T_610b4_row4_col4, #T_610b4_row4_col5, #T_610b4_row4_col6, #T_610b4_row4_col7, #T_610b4_row4_col8, #T_610b4_row4_col9, #T_610b4_row4_col10, #T_610b4_row4_col11, #T_610b4_row4_col12, #T_610b4_row5_col0, #T_610b4_row5_col1, #T_610b4_row5_col2, #T_610b4_row5_col3, #T_610b4_row5_col4, #T_610b4_row5_col5, #T_610b4_row5_col6, #T_610b4_row5_col7, #T_610b4_row5_col8, #T_610b4_row5_col9, #T_610b4_row5_col10, #T_610b4_row5_col11, #T_610b4_row5_col12, #T_610b4_row6_col0, #T_610b4_row6_col1, #T_610b4_row6_col2, #T_610b4_row6_col3, #T_610b4_row6_col4, #T_610b4_row6_col5, #T_610b4_row6_col6, #T_610b4_row6_col7, #T_610b4_row6_col8, #T_610b4_row6_col9, #T_610b4_row6_col10, #T_610b4_row6_col11, #T_610b4_row6_col12, #T_610b4_row7_col0, #T_610b4_row7_col1, #T_610b4_row7_col2, #T_610b4_row7_col3, #T_610b4_row7_col4, #T_610b4_row7_col5, #T_610b4_row7_col6, #T_610b4_row7_col7, #T_610b4_row7_col8, #T_610b4_row7_col9, #T_610b4_row7_col10, #T_610b4_row7_col11, #T_610b4_row7_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_610b4">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_610b4_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_610b4_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_610b4_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_610b4_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_610b4_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_610b4_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_610b4_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_610b4_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_610b4_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_610b4_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_610b4_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_610b4_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_610b4_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_610b4_row0_col0" class="data row0 col0" >bridge1-nic_local_4-p1</td>
#       <td id="T_610b4_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_610b4_row0_col2" class="data row0 col2" >bridge1</td>
#       <td id="T_610b4_row0_col3" class="data row0 col3" >net2</td>
#       <td id="T_610b4_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_610b4_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_610b4_row0_col6" class="data row0 col6" ></td>
#       <td id="T_610b4_row0_col7" class="data row0 col7" >2A:0A:3A:00:30:B6</td>
#       <td id="T_610b4_row0_col8" class="data row0 col8" >enp9s0</td>
#       <td id="T_610b4_row0_col9" class="data row0 col9" >enp9s0</td>
#       <td id="T_610b4_row0_col10" class="data row0 col10" >fe80::280a:3aff:fe00:30b6</td>
#       <td id="T_610b4_row0_col11" class="data row0 col11" >4</td>
#       <td id="T_610b4_row0_col12" class="data row0 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_610b4_row1_col0" class="data row1 col0" >bridge1-nic_local_2-p1</td>
#       <td id="T_610b4_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_610b4_row1_col2" class="data row1 col2" >bridge1</td>
#       <td id="T_610b4_row1_col3" class="data row1 col3" >net3</td>
#       <td id="T_610b4_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_610b4_row1_col5" class="data row1 col5" >config</td>
#       <td id="T_610b4_row1_col6" class="data row1 col6" ></td>
#       <td id="T_610b4_row1_col7" class="data row1 col7" >26:D7:09:AF:5B:2C</td>
#       <td id="T_610b4_row1_col8" class="data row1 col8" >enp8s0</td>
#       <td id="T_610b4_row1_col9" class="data row1 col9" >enp8s0</td>
#       <td id="T_610b4_row1_col10" class="data row1 col10" >fe80::24d7:9ff:feaf:5b2c</td>
#       <td id="T_610b4_row1_col11" class="data row1 col11" >4</td>
#       <td id="T_610b4_row1_col12" class="data row1 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_610b4_row2_col0" class="data row2 col0" >bridge1-nic_local_3-p1</td>
#       <td id="T_610b4_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_610b4_row2_col2" class="data row2 col2" >bridge1</td>
#       <td id="T_610b4_row2_col3" class="data row2 col3" >net0</td>
#       <td id="T_610b4_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_610b4_row2_col5" class="data row2 col5" >config</td>
#       <td id="T_610b4_row2_col6" class="data row2 col6" ></td>
#       <td id="T_610b4_row2_col7" class="data row2 col7" >2E:21:6F:AC:F9:09</td>
#       <td id="T_610b4_row2_col8" class="data row2 col8" >enp10s0</td>
#       <td id="T_610b4_row2_col9" class="data row2 col9" >enp10s0</td>
#       <td id="T_610b4_row2_col10" class="data row2 col10" >fe80::2c21:6fff:feac:f909</td>
#       <td id="T_610b4_row2_col11" class="data row2 col11" >4</td>
#       <td id="T_610b4_row2_col12" class="data row2 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_610b4_row3_col0" class="data row3 col0" >bridge1-nic_local_1-p1</td>
#       <td id="T_610b4_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_610b4_row3_col2" class="data row3 col2" >bridge1</td>
#       <td id="T_610b4_row3_col3" class="data row3 col3" >net1</td>
#       <td id="T_610b4_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_610b4_row3_col5" class="data row3 col5" >config</td>
#       <td id="T_610b4_row3_col6" class="data row3 col6" ></td>
#       <td id="T_610b4_row3_col7" class="data row3 col7" >12:A6:77:A5:47:9F</td>
#       <td id="T_610b4_row3_col8" class="data row3 col8" >enp7s0</td>
#       <td id="T_610b4_row3_col9" class="data row3 col9" >enp7s0</td>
#       <td id="T_610b4_row3_col10" class="data row3 col10" >fe80::10a6:77ff:fea5:479f</td>
#       <td id="T_610b4_row3_col11" class="data row3 col11" >4</td>
#       <td id="T_610b4_row3_col12" class="data row3 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_610b4_row4_col0" class="data row4 col0" >newy1-nic_local-p1</td>
#       <td id="T_610b4_row4_col1" class="data row4 col1" >p1</td>
#       <td id="T_610b4_row4_col2" class="data row4 col2" >newy1</td>
#       <td id="T_610b4_row4_col3" class="data row4 col3" >net0</td>
#       <td id="T_610b4_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_610b4_row4_col5" class="data row
# Time to print interfaces 340 seconds

# %% [markdown]
# # OVS

# %%
try:
    for node in slice.get_nodes():
        if node.get_name().startswith("bridge"):
            stdout, stderr = node.execute('yes | sudo apt-get -y update && sudo apt-get upgrade', quiet=True) 
            stdout, stderr = node.execute('yes | sudo apt-get -y install openvswitch-switch openvswitch-common', quiet=True)
            stdout, stderr = node.execute('sudo apt-get -y install net-tools', quiet=True)
            print(f"done bridge: {node.get_name()}")
    print("Done")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# done bridge: bridge1
# Done

# %%
bridge1 = slice.get_node(name=bridge1_name)
stdout, stderr = bridge1.execute('sudo ovs-vsctl add-br br0')
for interface in bridge1.get_interfaces():
    stdout, stderr = bridge1.execute(f'sudo ovs-vsctl add-port br0 {interface.get_physical_os_interface_name()}')
    #Remove IP addresses for all interfaces
    stdout, stderr = bridge1.execute(f'sudo ifconfig {interface.get_physical_os_interface_name()} 0')
    
#bring the bridge up
stdout, stderr = bridge1.execute('sudo ifconfig br0 up')

print("Done")
# Out:
# Done

# %%
stdout, stderr = bridge1.execute('sudo ovs-vsctl set bridge br0 stp_enable=true')

# %%
stdout, stderr = bridge1.execute('sudo ovs-appctl stp/show')
# Out:
# ---- br0 ----
# Root ID:
#   stp-priority  32768
#   stp-system-id   a6:7d:01:5a:8f:4f
#   stp-hello-time  2s
#   stp-max-age     20s
#   stp-fwd-delay   15s
#   This bridge is the root
#
# Bridge ID:
#   stp-priority  32768
#   stp-system-id   a6:7d:01:5a:8f:4f
#   stp-hello-time  2s
#   stp-max-age     20s
#   stp-fwd-delay   15s
#
#   Interface  Role       State      Cost  Pri.Nbr
#   ---------- ---------- ---------- ----- -------
#   enp7s0     designated listening  2     128.1
#   enp8s0     designated listening  2     128.2
#   enp10s0    designated listening  2     128.3
#   enp9s0     designated listening  2     128.4

# %% [markdown]
# # Host Setup

# %%
networks = [
    "10.10.10.1/24",
    "10.10.10.2/24",
    "10.10.10.3/24",
    "10.10.10.4/24"
]
for i in range(4):
    host = slice.get_node(name=f'{site1.lower()}{i+1}')
    stdout, stderr = host.execute('sudo apt-get -y install net-tools', quiet=True)
    stdout, stderr = host.execute(f'sudo ip link set dev {host.get_interfaces()[0].get_physical_os_interface_name()} up', quiet=True)
    stdout, stderr = host.execute(f'sudo ip addr add {networks[i]} dev {host.get_interfaces()[0].get_physical_os_interface_name()}', quiet=True)

# %%
host1 = slice.get_node(name=f'{site1.lower()}1')
stdout, stderr = host1.execute('ping 10.10.10.2 -c 5')
# Out:
# PING 10.10.10.2 (10.10.10.2) 56(84) bytes of data.
# 64 bytes from 10.10.10.2: icmp_seq=1 ttl=64 time=0.507 ms
# 64 bytes from 10.10.10.2: icmp_seq=2 ttl=64 time=0.191 ms
# 64 bytes from 10.10.10.2: icmp_seq=3 ttl=64 time=0.310 ms
# 64 bytes from 10.10.10.2: icmp_seq=4 ttl=64 time=0.183 ms
# 64 bytes from 10.10.10.2: icmp_seq=5 ttl=64 time=0.175 ms
#
# --- 10.10.10.2 ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4093ms
# rtt min/avg/max/mdev = 0.175/0.273/0.507/0.126 ms

# %%
stdout, stderr = host1.execute('ping 10.10.10.3 -c 5')
# Out:
# PING 10.10.10.3 (10.10.10.3) 56(84) bytes of data.
# 64 bytes from 10.10.10.3: icmp_seq=1 ttl=64 time=0.534 ms
# 64 bytes from 10.10.10.3: icmp_seq=2 ttl=64 time=0.195 ms
# 64 bytes from 10.10.10.3: icmp_seq=3 ttl=64 time=0.202 ms
# 64 bytes from 10.10.10.3: icmp_seq=4 ttl=64 time=0.154 ms
# 64 bytes from 10.10.10.3: icmp_seq=5 ttl=64 time=0.180 ms
#
# --- 10.10.10.3 ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4088ms
# rtt min/avg/max/mdev = 0.154/0.253/0.534/0.141 ms

# %%
stdout, stderr = host1.execute('ping 10.10.10.4 -c 5')
# Out:
# PING 10.10.10.4 (10.10.10.4) 56(84) bytes of data.
# 64 bytes from 10.10.10.4: icmp_seq=1 ttl=64 time=0.347 ms
# 64 bytes from 10.10.10.4: icmp_seq=2 ttl=64 time=0.179 ms
# 64 bytes from 10.10.10.4: icmp_seq=3 ttl=64 time=0.185 ms
# 64 bytes from 10.10.10.4: icmp_seq=4 ttl=64 time=0.173 ms
# 64 bytes from 10.10.10.4: icmp_seq=5 ttl=64 time=0.179 ms
#
# --- 10.10.10.4 ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4078ms
# rtt min/avg/max/mdev = 0.173/0.212/0.347/0.067 ms
